# %%
import pandas as pd
df = pd.read_csv('/Users/taehayeong/Desktop/PILAB/RobustnessAD/results/winclip/auroc_visa.csv')
df.sort_values(by='I-AUROC', ascending=False, inplace=True)
df
# Out:
#          class   I-AUROC
# 13     leather  1.000000
# 11        tile  0.999278
# 14      carpet  0.993178
# 12        grid  0.991646
# 0       bottle  0.985714
# 10        wood  0.976316
# 4    metal_nut  0.954545
# 3     hazelnut  0.924643
# 9       zipper  0.910452
# 8   transistor  0.893542
# 7   toothbrush  0.852778
# 1        cable  0.852043
# 5         pill  0.813421
# 6        screw  0.719922
# 2      capsule  0.686478
