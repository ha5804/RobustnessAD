# %%
import pandas as pd

ano = pd.read_csv("../results/anomalyclip/auroc_mvtec.csv")
ada = pd.read_csv("../results/adaptclip/auroc_mvtec.csv")
win = pd.read_csv("../results/winclip/auroc_mvtec.csv")
ano.sort_values(by = 'I_AUROC', ascending=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 6
#       4 ada = pd.read_csv("../results/adaptclip/auroc_mvtec.csv")
#       5 win = pd.read_csv("../results/winclip/auroc_mvtec.csv")
# ----> 6 ano.sort_values(ascending=True)
#
# TypeError: DataFrame.sort_values() missing 1 required positional argument: 'by'
